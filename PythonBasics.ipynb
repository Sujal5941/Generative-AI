# %% [markdown]
# ###**DataType**

# %%
name = 'mike'
print(name)
# Out:
# mike

# %%
type(name)
# Out:
# str

# %% [markdown]
# ### **Input in python**

# %%
name = input('Enter your name :')
print('welcome ',name)
# Out:
# Enter your name :mike
# welcome  mike

# %%
name
# Out:
# 'mike'

# %%
type(name)
# Out:
# str

# %%
a = True
b = 'True'

# %%
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# ### **Typecasting**

# %%
acc = 91.4
print(acc)
acc = int(acc)    # Typecasting leads to the data loss
print(acc)
# Out:
# 91.4
# 91

# %%
var = 2
type(var)
# Out:
# int

# %%
var1 = float(var)
print(var1)
type(var1)
# Out:
# 2.0
# float

# %%
var = 2.9
var_int = int(var)
print(var_int)
# Out:
# 2

# %%
var = 2
new_var = str(var)
new_var
# Out:
# '2'

# %%
type(new_var)
# Out:
# str

# %%
int("2")
# Out:
# 2

# %%
# Convert the float value into the String into Integer
# int("2.2") will give error
int(float("2.2"))
# Out:
# 2

# %% [markdown]
# ### **Accessing String Object**

# %%
string_var = 'HELLO'

# %%
string_var[0]
# Out:
# 'H'

# %%
string_var[-5]
# Out:
# 'H'

# %%
# string_var[0] = 'Y'  <--- string is immutable
