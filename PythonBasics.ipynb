# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujal5941/Generative-AI/blob/main/PythonBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**DataType**

# %%
name = 'mike'
print(name)
# Out:
# mike
