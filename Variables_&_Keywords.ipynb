# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujal5941/Generative-AI/blob/main/Variables_%26_Keywords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Variables & Keywords**

# %% [markdown]
# A Python variable is a reserved memory Loaction to store values. In other words, a variable in a python program gives data to the computer for processing

# %%
a = 'hello world'

# %%
type(a)
# Out:
# str

# %%
my_age =  21
print(my_age)
# Out:
# 21

# %%
type(my_age)
# Out:
# int

# %%
my_age = '21'
print(my_age)
# Out:
# 21

# %%
print(type(my_age))
# Out:
# <class 'str'>

# %%
# Variable Name cannot strat with the number --> eg: 5a -- invalid
a5 = 10
a5
# Out:
# 10

# %%
# variable names are not case Sensitive
a = 10
A= 15
print(a)
print(A)
# Out:
# 10
# 15

# %%
a = 4
b = 5
c= a+b
print(c)
# Out:
# 9

# %%
# Function
def sum_function(a,b):
  c = a+b
  return c

sum_function(4,5)
# Out:
# 9

# %%
# Variable cannot contain special Character @#%!$^&*,etc except _
# eg @s123 invalid
s123 = "Hello"
s123
# Out:
# 'Hello'

# %%
# Cannot use keyword as variable
# eg type = 23 invalid
