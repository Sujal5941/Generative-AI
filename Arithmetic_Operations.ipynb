# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujal5941/Generative-AI/blob/main/Arithmetic_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Basic Operations Addition, Subtraction, multiplication, division, floor division, Modulus, Exponentiation,etc**

# %%
a = 10
b = 2
a+b # Addition
# Out:
# 12

# %%
a - b # subtraction
# Out:
# 8

# %%
a*b # multiplication
# Out:
# 20

# %%
a/b # division <--- division operation automatically convert the values in float
# Out:
# 5.0

# %%
a= 10
b = 3
a // b # floor division <--- convert the values after divison into integer and return the floor value
# celling value convert the following in (10/3) -> 4
# Out:
# 3

# %%
a % b   # return the remainder of the divison
# Out:
# 1

# %%
a**b  # returns a to the power b
# Out:
# 1000

# %%
# BODMAS
print((4*5)-9+6/7)
# Out:
# 11.857142857142858

# %%
#  H0w caluation is perform
a=(4*5)

# %%
b = 6/7
b
# Out:
# 0.8571428571428571

# %%
a = a - 9
a
# Out:
# 11

# %%
a+b
# Out:
# 11.857142857142858

# %%
# eg 2
print(4 % (1 + 9)**2 - 60// (7+2))
# Out:
# -2
